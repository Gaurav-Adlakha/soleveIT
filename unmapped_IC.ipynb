# %%
cd static
# Out:
# /app/data/static

# %%
ls -ltr
# Out:
# total 23888
# -rw-r--r-- 1 solveit solveit  314252 Mar 30 07:54  gaurav_img.jpg
# -rw-r--r-- 1 solveit solveit    4065 Apr  2 05:36  blog-post.qmd
# -rw-r--r-- 1 solveit solveit    6988 Apr  2 05:37  rag-blog.qmd
# -rw-r--r-- 1 solveit solveit    8781 Apr  9 10:30  PSSIS.GOLDTEMPLATE_STAFF.csv
# -rw-r--r-- 1 solveit solveit 4572756 Apr  9 10:32  PSESSENTIALS_OPERATIONAL_ICSCRUB2_TABLES_IDENTIFIED_CMAPPING.csv
# -rw-r--r-- 1 solveit solveit    7862 Apr 11 03:19  images.jpeg
# drwxr-xr-x 2 solveit solveit       6 Apr 11 03:40  uploads/
# -rw-r--r-- 1 solveit solveit 8705924 Apr 12 06:14 'case study-2024.zip'
# drwxr-xr-x 2 solveit solveit     105 Apr 12 06:14 'case study-2024'/
# -rw-r--r-- 1 solveit solveit     796 Apr 16 08:13  _PSESSENTIALS.ICSCRUB2.CODESET_MAPPING.csv
# -rw-r--r-- 1 solveit solveit    2643 Apr 16 08:13  PSESSENTIALS.ICSCRUB2.DATA_MAPPING.csv
# -rw-r--r-- 1 solveit solveit    4019 Apr 16 10:37  sql_transformation_prompt.md
# ...

# %%
from utils import *

# %%
df = pd.read_csv('unmapped_IC.csv')

# %%
df
# Out:
#                SOURCE_TABLE SOURCE_CODE  ...  SOURCE_SIS_TYPE  SOURCE_SIS_VERSION
# 0    BEHAVIORRESOLUTIONTYPE          RB  ...  Infinite Campus                 NaN
# 1          ENDSTATUSMAPPING           0  ...  Infinite Campus                 NaN
# 2          ENDSTATUSMAPPING           6  ...  Infinite Campus                 NaN
# 3          ENDSTATUSMAPPING           7  ...  Infinite Campus                 NaN
# 4          ENDSTATUSMAPPING          12  ...  Infinite Campus                 NaN
# ..                      ...         ...  ...              ...                 ...
# 620                     FEE           A  ...  Infinite Campus                 NaN
# 621                     FEE           A  ...  Infinite Campus                 NaN
# 622                     FEE           A  ...  Infinite Campus                 NaN
# 623                     FEE           A  ...  Infinite Campus                 NaN
# ...

# %%
df['SOURCE_TABLE'].value_counts()
# Out:
# SOURCE_TABLE
# SCOREGROUP                171
# TESTRESULT                156
# TEST                      107
# FEE                        94
# ENDSTATUSMAPPING           37
# VACCINEMAPPING             34
# RUBRIC                     20
# STARTSTATUSMAPPING          5
# BEHAVIORRESOLUTIONTYPE      1
# Name: count, dtype: int64

# %%
df['SOURCE_TABLE'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='SOURCE_TABLE'>

# %%
df[df['SOURCE_TABLE']=='ENDSTATUSMAPPING']
# Out:
#         SOURCE_TABLE SOURCE_CODE  ...  SOURCE_SIS_TYPE  SOURCE_SIS_VERSION
# 1   ENDSTATUSMAPPING           0  ...  Infinite Campus                 NaN
# 2   ENDSTATUSMAPPING           6  ...  Infinite Campus                 NaN
# 3   ENDSTATUSMAPPING           7  ...  Infinite Campus                 NaN
# 4   ENDSTATUSMAPPING          12  ...  Infinite Campus                 NaN
# 5   ENDSTATUSMAPPING          13  ...  Infinite Campus                 NaN
# 6   ENDSTATUSMAPPING          14  ...  Infinite Campus                 NaN
# 7   ENDSTATUSMAPPING          15  ...  Infinite Campus                 NaN
# 8   ENDSTATUSMAPPING          17  ...  Infinite Campus                 NaN
# 9   ENDSTATUSMAPPING          18  ...  Infinite Campus                 NaN
# 10  ENDSTATUSMAPPING          21  ...  Infinite Campus                 NaN
# 11  ENDSTATUSMAPPING          22  ...  Infinite Campus                 NaN
# ...

# %%
df[df['SOURCE_TABLE']=='ENDSTATUSMAPPING']
# Out:
#         SOURCE_TABLE SOURCE_CODE  ...  SOURCE_SIS_TYPE  SOURCE_SIS_VERSION
# 1   ENDSTATUSMAPPING           0  ...  Infinite Campus                 NaN
# 2   ENDSTATUSMAPPING           6  ...  Infinite Campus                 NaN
# 3   ENDSTATUSMAPPING           7  ...  Infinite Campus                 NaN
# 4   ENDSTATUSMAPPING          12  ...  Infinite Campus                 NaN
# 5   ENDSTATUSMAPPING          13  ...  Infinite Campus                 NaN
# 6   ENDSTATUSMAPPING          14  ...  Infinite Campus                 NaN
# 7   ENDSTATUSMAPPING          15  ...  Infinite Campus                 NaN
# 8   ENDSTATUSMAPPING          17  ...  Infinite Campus                 NaN
# 9   ENDSTATUSMAPPING          18  ...  Infinite Campus                 NaN
# 10  ENDSTATUSMAPPING          21  ...  Infinite Campus                 NaN
# 11  ENDSTATUSMAPPING          22  ...  Infinite Campus                 NaN
# ...

# %%
cat utils.py
# Out:
# from fastcore.utils import L,first, last, groupby, mul, add, sub, truediv, patch, store_attr, BasicRepr
# from aocd import get_data
# import pandas as pd
# import fastcore.all as fc, re, math, itertools, functools, numpy as np, types, typing, dataclasses, matplotlib.pyplot as plt,collections,regex
# from regex import search
# from collections import Counter
# from collections.abc import Iterable
# np.set_printoptions(linewidth=150)
# plt.rcParams['figure.dpi'] = 50
# np.set_printoptions(precision=2, suppress=True)
#
# import torch, numpy as np, pandas as pd
# np.set_printoptions(linewidth=140)
# torch.set_printoptions(linewidth=140, sci_mode=False, edgeitems=7)
# pd.set_option('display.width', 140)
#
# # import torch
# # torch.set_printoptions(precision=2, sci_mode=False)
#
# # Add your new functions/modifications here
#
# # for plot
# from ipywidgets import interact
# # from fastai.basics import *
#
# plt.rc('figure', dpi=90)
#
# ...

# %%
pretty_df(df[df['SOURCE_TABLE']=='ENDSTATUSMAPPING'], rows=40)
# Out:
# <style type="text/css">
# #T_fb53d th {
#   font-weight: bold;
#   background-color: #4CAF50;
#   color: white;
#   padding: 10px;
#   text-align: left;
# }
# #T_fb53d td {
#   padding: 8px;
#   border-bottom: 1px solid #ddd;
# }
# #T_fb53d tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_fb53d tr:hover {
#   background-color: #ddd;
# }
# </style>
# <table id="T_fb53d" class="dataframe" style="width:100%; border-collapse: collapse">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb53d_level0_col0" class="col_heading level0 col0" >SOURCE_TABLE</th>
#       <th id="T_fb53d_level0_col1" class="col_heading level0 col1" >SOURCE_CODE</th>
#       <th id="T_fb53d_level0_col2" class="col_heading level0 col2" >SOURCE_DESC</th>
#       <th id="T_fb53d_level0_col3" class="col_heading level0 col3" >TARGET_CODETYPE</th>
#       <th id="T_fb53d_level0_col4" class="col_heading level0 col4" >TARGET_CODE</th>
# ...

# %%
ls -ltr
# Out:
# total 24504
# -rw-r--r-- 1 solveit solveit  314252 Mar 30 07:54  gaurav_img.jpg
# -rw-r--r-- 1 solveit solveit    4065 Apr  2 05:36  blog-post.qmd
# -rw-r--r-- 1 solveit solveit    6988 Apr  2 05:37  rag-blog.qmd
# -rw-r--r-- 1 solveit solveit    8781 Apr  9 10:30  PSSIS.GOLDTEMPLATE_STAFF.csv
# -rw-r--r-- 1 solveit solveit 4572756 Apr  9 10:32  PSESSENTIALS_OPERATIONAL_ICSCRUB2_TABLES_IDENTIFIED_CMAPPING.csv
# -rw-r--r-- 1 solveit solveit    7862 Apr 11 03:19  images.jpeg
# drwxr-xr-x 2 solveit solveit       6 Apr 11 03:40  uploads/
# -rw-r--r-- 1 solveit solveit 8705924 Apr 12 06:14 'case study-2024.zip'
# drwxr-xr-x 2 solveit solveit     105 Apr 12 06:14 'case study-2024'/
# -rw-r--r-- 1 solveit solveit     796 Apr 16 08:13  _PSESSENTIALS.ICSCRUB2.CODESET_MAPPING.csv
# -rw-r--r-- 1 solveit solveit    2643 Apr 16 08:13  PSESSENTIALS.ICSCRUB2.DATA_MAPPING.csv
# -rw-r--r-- 1 solveit solveit    4019 Apr 16 10:37  sql_transformation_prompt.md
# ...

# %%
mv 'result (10).csv to_check.csv
# Out:
# /usr/bin/sh: 1: Syntax error: Unterminated quoted string
# /usr/local/lib/python3.11/site-packages/lancedb/__init__.py:220: UserWarning: lance is not fork-safe. If you are using multiprocessing, use spawn instead.
#   warnings.warn(

# %%
ls -ltr
# Out:
# total 24504
# -rw-r--r-- 1 solveit solveit  314252 Mar 30 07:54  gaurav_img.jpg
# -rw-r--r-- 1 solveit solveit    4065 Apr  2 05:36  blog-post.qmd
# -rw-r--r-- 1 solveit solveit    6988 Apr  2 05:37  rag-blog.qmd
# -rw-r--r-- 1 solveit solveit    8781 Apr  9 10:30  PSSIS.GOLDTEMPLATE_STAFF.csv
# -rw-r--r-- 1 solveit solveit 4572756 Apr  9 10:32  PSESSENTIALS_OPERATIONAL_ICSCRUB2_TABLES_IDENTIFIED_CMAPPING.csv
# -rw-r--r-- 1 solveit solveit    7862 Apr 11 03:19  images.jpeg
# drwxr-xr-x 2 solveit solveit       6 Apr 11 03:40  uploads/
# -rw-r--r-- 1 solveit solveit 8705924 Apr 12 06:14 'case study-2024.zip'
# drwxr-xr-x 2 solveit solveit     105 Apr 12 06:14 'case study-2024'/
# -rw-r--r-- 1 solveit solveit     796 Apr 16 08:13  _PSESSENTIALS.ICSCRUB2.CODESET_MAPPING.csv
# -rw-r--r-- 1 solveit solveit    2643 Apr 16 08:13  PSESSENTIALS.ICSCRUB2.DATA_MAPPING.csv
# -rw-r--r-- 1 solveit solveit    4019 Apr 16 10:37  sql_transformation_prompt.md
# ...

# %% [markdown]
# SOURCE_TABLE	SOURCE_CODE	SOURCE_DESC	TARGET_CODETYPE	TARGET_CODE	TARGET_DESC
# ENDSTATUSMAPPING	1	Change in grade level (ia 19-20)	ExitCode	PR	Promoted
# ENDSTATUSMAPPING	2	Transfer to another school in district (ia 19-20)	ExitCode	TD	Transfer in District
# ENDSTATUSMAPPING	3	Transferred to an approved nonpublic school	ExitCode	TS	Transfer in state
# ENDSTATUSMAPPING	4	Student moved outside of the district, transferred to another Minnesota district	ExitCode	TD	Transfer in District
# ENDSTATUSMAPPING	5	Student moved to another state and enrolled in school, or student moved out of the country	ExitCode	TO	Transfer out of state
# ENDSTATUSMAPPING	8	Student graduated from a public school district	ExitCode	GR	Graduated
# ENDSTATUSMAPPING	11	Student deceased	ExitCode	DE	Death
# ENDSTATUSMAPPING	16	Student expelled and did not return during the year	ExitCode	EX	Expulsion
# ENDSTATUSMAPPING	20	Student transferred to another district/state but did not move	ExitCode	TD	Transfer in District
# TESTRESULT	Pass	Pass	ExitCode	PR	Promoted
# TESTRESULT	Pass	Pass	ExitCode	PR	Promoted
# TESTRESULT	Pass	Pass	ExitCode	PR	Promoted
# TESTRESULT	Pass	Pass	ExitCode	PR	Promoted
# TESTRESULT	Pass	Pass	ExitCode	PR	Promoted
# TESTRESULT	P	Pass	ExitCode	PR	Promoted
# TESTRESULT	P	Pass	ExitCode	PR	Promoted
# TESTRESULT	P	Pass	ExitCode	PR	Promoted
# TESTRESULT	Y	Pass	ExitCode	PR	Promoted
# STARTSTATUSMAPPING	2	Most recent enrollment was in a school in another state	ExitCode	TO	Transfer out of state
# STARTSTATUSMAPPING	4	Most Recent enrollment was in a school in another Minnesota district or charter school	ExitCode	TD	Transfer in district
# STARTSTATUSMAPPING	7	Last enrolled before last year (ia19-20)	ExitCode	RE	Retained
# STARTSTATUSMAPPING	11	Midyear transfer from MN nonpublic school (ia19-20)	ExitCode	TS	Transfer in state
# STARTSTATUSMAPPING	12	Midyear transfer from other state (ia19-20)	ExitCode	TO	Transfer out of state
# STARTSTATUSMAPPING	14	Midyear transfer from other MN school district (ia19-20)	ExitCode	TD	Transfer in district
# STARTSTATUSMAPPING	21	Midyear transfer from school in this district (ia19-20)	ExitCode	TD	Transfer in district
# STARTSTATUSMAPPING	23	Midyear change in district of residence (ia19-20)	ExitCode	TD	Transfer in district
# STARTSTATUSMAPPING	24	Re-enrollment into the same school or inter-district transfer during the same school year	ExitCode	TD	Transfer in district
# SCOREGROUP	NA	NA	Ethnicity	NA	Not Assessed
# SCOREGROUP	F	Fail	ExitCode	F	Fail
# SCOREGROUP	NA	Not Assessed	Ethnicity	NA	Not Assessed
# SCOREGROUP	NA	Not Assessed	Ethnicity	NA	Not Assessed
# SCOREGROUP	F	Failing	ExitCode	F	Fail
# SCOREGROUP	F	F	ExitCode	F	Fail
# ENDSTATUSMAPPING	41	Dropout re-enrolled somewhere by 10/1 (ia19-20 use 18)	EntryCode	RT	Returning Student
# STARTSTATUSMAPPING	5	Never been enrolled in a school before, regardless of age	EntryCode	OE	Original Entry
# STARTSTATUSMAPPING	6	Age 6 or older as of 9/1, never before in school (ia19-20)	EntryCode	OE	Original Entry
# SCOREGROUP	P	Pass	EntryCode	P	Promoted
# SCOREGROUP	P	Pass	EntryCode	P	Promoted
# SCOREGROUP	P	Pass	EntryCode	P	Promoted
# BEHAVIORRESOLUTIONTYPE	OSS	Out of School Suspension	EntryCode	Ved1	Ved2

# %% [markdown]
# read the data in pandas df
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Looking at the image, I see a horizontal bar chart showing the count of different source tables in a dataset. The source tables are listed on the y-axis, and their frequencies are shown on the x-axis.
#
# Based on the information displayed in the chart and the code that's been run, it appears you're working with a dataset related to student information systems or educational data mapping.
#
# I can see that you've already loaded the data into a pandas DataFrame called `df` using:
#
# ```python
# df = pd.read_csv('unmapped_IC.csv')
# ```
#
# The bar chart shows that the most frequent source tables in your dataset are:
# 1. SCOREGROUP (with the highest count, around 170)
# 2. TESTRESULT (around 155)
# 3. TEST (around 105)
# 4. FEE (around 95)
# 5. ENDSTATUSMAPPING (around 35)
# 6. VACCINEMAPPING (around 35)
# 7. RUBRIC (around 20)
# 8. STARTSTATUSMAPPING (very few)
# 9. BEHAVIORRESOLUTIONTYPE (just 1)
#
# Would you like me to help you analyze this data further or perform specific operations on the DataFrame?

# %%
ls
# Out:
# 'Assessment Champion Model Dataset.csv'
# 'Assessment Holdout Dataset.csv'
# 'Assessment Modeling Dataset.csv'
#  EMPLOYEE_schema.csv
# 'FU-Technical Assessment - Applied Data Scientist-250425-033739.pdf'
#  PSESSENTIALS.ICSCRUB2.DATA_MAPPING.csv
#  PSESSENTIALS_OPERATIONAL_ICSCRUB2_TABLES_IDENTIFIED_CMAPPING.csv
#  PSSIS.GOLDTEMPLATE_STAFF.csv
#  SPECIALED_schema.csv
#  USERACCOUNT_schema.csv
#  _PSESSENTIALS.ICSCRUB2.CODESET_MAPPING.csv
#  __MACOSX/
#  assessment_data/
#  assessment_datasets.zip
#  blog-post.qmd
# 'case study-2024'/
# 'case study-2024.zip'
#  employee_sample_data.csv
#  employment_sample_data.csv
#  employment_schema.csv
#  ensemble_submission.csv
#  gaurav_img.jpg
#  images.jpeg
#  mapped.csv
#  models/
#  processed_df_C_R.csv
#  rag-blog.qmd
# 'result (10).csv'
#  sql_transformation_prompt.md
#  staff_teacher_sample_data.csv
#  staff_teacher_schemna.csv
#  submission.csv
#  unmapped_IC.csv
#  uploads/
#  userAccount_sample_data.csv
#  utils.py
# ...

# %%
ls -ltr
# Out:
# total 24512
# -rw-r--r-- 1 solveit solveit  314252 Mar 30 07:54  gaurav_img.jpg
# -rw-r--r-- 1 solveit solveit    4065 Apr  2 05:36  blog-post.qmd
# -rw-r--r-- 1 solveit solveit    6988 Apr  2 05:37  rag-blog.qmd
# -rw-r--r-- 1 solveit solveit    8781 Apr  9 10:30  PSSIS.GOLDTEMPLATE_STAFF.csv
# -rw-r--r-- 1 solveit solveit 4572756 Apr  9 10:32  PSESSENTIALS_OPERATIONAL_ICSCRUB2_TABLES_IDENTIFIED_CMAPPING.csv
# -rw-r--r-- 1 solveit solveit    7862 Apr 11 03:19  images.jpeg
# drwxr-xr-x 2 solveit solveit       6 Apr 11 03:40  uploads/
# -rw-r--r-- 1 solveit solveit 8705924 Apr 12 06:14 'case study-2024.zip'
# drwxr-xr-x 2 solveit solveit     105 Apr 12 06:14 'case study-2024'/
# -rw-r--r-- 1 solveit solveit     796 Apr 16 08:13  _PSESSENTIALS.ICSCRUB2.CODESET_MAPPING.csv
# -rw-r--r-- 1 solveit solveit    2643 Apr 16 08:13  PSESSENTIALS.ICSCRUB2.DATA_MAPPING.csv
# -rw-r--r-- 1 solveit solveit    4019 Apr 16 10:37  sql_transformation_prompt.md
# ...

# %%
df= pd.read_csv('mapped.csv')

# %%
import pandas as pd

# %%
df
# Out:
#               SOURCE_TABLE SOURCE_CODE  ...  SOURCE_SIS_TYPE SOURCE_SIS_VERSION
# 0         ENDSTATUSMAPPING           1  ...  Infinite Campus             v1.9.9
# 1         ENDSTATUSMAPPING           2  ...  Infinite Campus             v1.9.9
# 2         ENDSTATUSMAPPING           3  ...  Infinite Campus             v1.9.9
# 3         ENDSTATUSMAPPING           4  ...  Infinite Campus             v1.9.9
# 4         ENDSTATUSMAPPING           5  ...  Infinite Campus             v1.9.9
# 5         ENDSTATUSMAPPING           8  ...  Infinite Campus             v1.9.9
# 6         ENDSTATUSMAPPING          11  ...  Infinite Campus             v1.9.9
# 7         ENDSTATUSMAPPING          16  ...  Infinite Campus             v1.9.9
# 8         ENDSTATUSMAPPING          20  ...  Infinite Campus             v1.9.9
# 9               TESTRESULT        Pass  ...  Infinite Campus             v1.9.9
# 10              TESTRESULT        Pass  ...  Infinite Campus             v1.9.9
# ...

# %%
df.T
# Out:
#                                                   0   ...                        39
# SOURCE_TABLE                        ENDSTATUSMAPPING  ...    BEHAVIORRESOLUTIONTYPE
# SOURCE_CODE                                        1  ...                       OSS
# SOURCE_DESC         Change in grade level (ia 19-20)  ...  Out of School Suspension
# TARGET_CODETYPE                             ExitCode  ...                 EntryCode
# TARGET_CODE                                       PR  ...                      Ved1
# TARGET_DESC                                 Promoted  ...                      Ved2
# CONFIDENCE                                       0.9  ...                       0.0
# SOURCE_SIS_TYPE                      Infinite Campus  ...           Infinite Campus
# SOURCE_SIS_VERSION                            v1.9.9  ...                       NaN
#
# [9 rows x 40 columns]

# %% [markdown]
# how can i pivot this data for each source table..
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# I can help you pivot this data by SOURCE_TABLE. Here's how to do it:
#
# ```python
# # Basic pivot table counting occurrences by SOURCE_TABLE
# pivot_count = df.pivot_table(index='SOURCE_TABLE', values='SOURCE_CODE', aggfunc='count')
# pivot_count
# ```
#
# For a more detailed pivot that shows mappings between source and target codes:
#
# ```python
# # Create a pivot showing how SOURCE_CODEs map to TARGET_CODEs for each SOURCE_TABLE
# pivot_mapping = df.pivot_table(
#     index=['SOURCE_TABLE', 'SOURCE_CODE', 'SOURCE_DESC'],
#     columns=['TARGET_CODETYPE', 'TARGET_CODE'],
#     values='CONFIDENCE',
#     aggfunc='first'
# )
# pivot_mapping
# ```
#
# If you want to see how many mappings exist for each TARGET_CODETYPE by SOURCE_TABLE:
#
# ```python
# # Count of mappings by SOURCE_TABLE and TARGET_CODETYPE
# code_type_counts = df.pivot_table(
#     index='SOURCE_TABLE',
#     columns='TARGET_CODETYPE',
#     values='SOURCE_CODE',
#     aggfunc='count'
# )
# code_type_counts
# ```
#
# You could also create a pivot showing confidence scores by source table:
#
# ```python
# # Average confidence by SOURCE_TABLE
# confidence_by_source = df.pivot_table(
#     index='SOURCE_TABLE',
#     values='CONFIDENCE',
#     aggfunc=['mean', 'min', 'max', 'count']
# )
# confidence_by_source
# ```
#
# Which of these approaches would be most useful for your analysis?

# %%
pivot_count = df.pivot_table(index='SOURCE_TABLE', values='SOURCE_CODE', aggfunc='count')
pivot_count
# Out:
#                         SOURCE_CODE
# SOURCE_TABLE
# BEHAVIORRESOLUTIONTYPE            1
# ENDSTATUSMAPPING                 10
# SCOREGROUP                        6
# STARTSTATUSMAPPING               11
# TESTRESULT                        9
